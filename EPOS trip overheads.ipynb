# %%
# %matplotlib inline  
import matplotlib as mpl
import matplotlib.pyplot as plt
from statistics import mean, median, variance 
plt.rcParams['figure.figsize'] = [10, 5]
import pprint

def get_data_from_file(file_name, flag):
    data = []
    with open(file_name, 'r') as results:
        for line in results:
            line = line.split(",")
            trip_duration = float(line[4])
            overhead = float(line[6])
            agent = line[7]
            preference = line[8].replace('\r', '').replace('\n', '')
            if flag == "d":
                data.append(trip_duration)
            if flag == "o":
                data.append(overhead)
    return data

# epos_altruistic = sorted(get_data_from_file("data/overheads.csv"))
# epos_altruistic = sorted(get_data_from_file("results/overhead_a0_b0.csv"))
# epos_selfish = sorted(get_data_from_file("results/overhead_a0_b1.csv"))
# epos_1 = sorted(get_data_from_file("results/overhead_a0_b0.9.csv"))
# epos_2 = sorted(get_data_from_file("results/overhead_a0_b0.5.csv"))

car1 = sorted(get_data_from_file("data/horizon_800_1target/overheads_200.csv","d"))
car2 = sorted(get_data_from_file("data/horizon_800_1target/overheads_1000.csv","d"))
car3 = sorted(get_data_from_file("data/horizon_800_1target/overheads_1400.csv","d"))
car4 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2000.csv","d"))
car5 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2300.csv","d"))
car6 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2500.csv","d"))

o1 = sorted(get_data_from_file("data/horizon_800_1target/overheads_200.csv","o"))
o2 = sorted(get_data_from_file("data/horizon_800_1target/overheads_1000.csv","o"))
o3 = sorted(get_data_from_file("data/horizon_800_1target/overheads_1400.csv","o"))
o4 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2000.csv","o"))
o5 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2300.csv","o"))
o6 = sorted(get_data_from_file("data/horizon_800_1target/overheads_2500.csv","o"))

# plt.plot(epos_altruistic, label="epos_altruistic")
# plt.plot(epos_selfish, label="epos_selfish")
# plt.plot(epos_1, label="epos_0_0.9")
# plt.plot(epos_2, label="epos_0_0.5")

plt.plot(car1, label="200 cars")
plt.plot(car2, label="1000 cars")
plt.plot(car3, label="1400 cars")
plt.plot(car4, label="2000 cars")
plt.plot(car5, label="2300 cars")
plt.plot(car6, label="2500 cars")
plt.title("trip Duration")
plt.legend(loc='best')
plt.show()

# print("Average overhead for 'epos_altruistic' is % s" % (mean(epos_altruistic))) 
# print("Average overhead for 'epos_selfish' is % s" % (mean(epos_selfish))) 
# print("Average overhead for 'epos_0_0.9' is % s" % (mean(epos_1))) 
# print("Average overhead for 'epos_0_0.5' is % s" % (mean(epos_2))) 

print("Average duration for '200 cars' is % s" % (mean(car1)))
print("Average duration for '1000 cars' is % s" % (mean(car2)))
print("Average duration for '1400 cars' is % s" % (mean(car3)))
print("Average duration for '2000 cars' is % s" % (mean(car4)))
print("Average duration for '2300 cars' is % s" % (mean(car5)))
print("Average duration for '2500 cars' is % s" % (mean(car6)))
print(" ")
print("Average overhead for '200 cars' is % s" % (mean(o1)))
print("Average overhead for '1000 cars' is % s" % (mean(o2)))
print("Average overhead for '1400 cars' is % s" % (mean(o3)))
print("Average overhead for '2000 cars' is % s" % (mean(o4)))
print("Average overhead for '2300 cars' is % s" % (mean(o5)))
print("Average overhead for '2500 cars' is % s" % (mean(o6)))
print("******")
# print("Median overhead for 'epos_altruistic' is % s" % (median(epos_altruistic))) 
# print("Median overhead for 'epos_selfish' is % s" % (median(epos_selfish))) 
# print("Median overhead for 'epos_0_0.9' is % s" % (median(epos_1))) 
# print("Median overhead for 'epos_0_0.5' is % s" % (median(epos_2))) 

print("Median duration for '200 cars' is % s" % (median(car1)))
print("Median duration for '1000 cars' is % s" % (median(car2)))
print("Median duration for '1400 cars' is % s" % (median(car3)))
print("Median duration for '2000 cars' is % s" % (median(car4)))
print("Median duration for '2300 cars' is % s" % (median(car5)))
print("Median duration for '2500 cars' is % s" % (median(car6)))
print(" ")
print("Median overhead for '200 cars' is % s" % (median(o1)))
print("Median overhead for '1000 cars' is % s" % (median(o2)))
print("Median overhead for '1400 cars' is % s" % (median(o3)))
print("Median overhead for '2000 cars' is % s" % (median(o4)))
print("Median overhead for '2300 cars' is % s" % (median(o5)))
print("Median overhead for '2500 cars' is % s" % (median(o6)))
print("******")
# print("Variance of overhead for 'epos_altruistic' is % s" % (variance(epos_altruistic))) 
# print("Variance of overhead for 'epos_selfish' is % s" % (variance(epos_selfish))) 
# print("Variance of overhead for 'epos_0_0.9' is % s" % (variance(epos_1))) 
# print("Variance of overhead for 'epos_0_0.5' is % s" % (variance(epos_2))) 

print("variance of duration for '200 cars' is % s" % (variance(car1)))
print("variance of duration for '1000 cars' is % s" % (variance(car2)))
print("variance of duration for '1400 cars' is % s" % (variance(car3)))
print("variance of duration for '2000 cars' is % s" % (variance(car4)))
print("variance of duration for '2300 cars' is % s" % (variance(car5)))
print("variance of duration for '2500 cars' is % s" % (variance(car6)))
print(" ")
print("variance of overhead for '200 cars' is % s" % (variance(o1)))
print("variance of overhead for '1000 cars' is % s" % (variance(o2)))
print("variance of overhead for '1400 cars' is % s" % (variance(o3)))
print("variance of overhead for '2000 cars' is % s" % (variance(o4)))
print("variance of overhead for '2300 cars' is % s" % (variance(o5)))
print("variance of overhead for '2500 cars' is % s" % (variance(o6)))
# Out:
# Average duration for '200 cars' is 352.275229358
# Average duration for '1000 cars' is 490.528301887
# Average duration for '1400 cars' is 498.155555556
# Average duration for '2000 cars' is 493.080769231
# Average duration for '2300 cars' is 487.958646617
# Average duration for '2500 cars' is 469.626811594
#
# Average overhead for '200 cars' is 1.63084152038
# Average overhead for '1000 cars' is 2.46147107179
# Average overhead for '1400 cars' is 2.52135381923
# Average overhead for '2000 cars' is 2.63020591524
# Average overhead for '2300 cars' is 2.57628940296
# Average overhead for '2500 cars' is 2.54144812537
# ******
# Median duration for '200 cars' is 326.0
# Median duration for '1000 cars' is 480.0
# Median duration for '1400 cars' is 506.0
# Median duration for '2000 cars' is 493.5
# Median duration for '2300 cars' is 485.5
# Median duration for '2500 cars' is 463.0
#
# Median overhead for '200 cars' is 1.46798454832
# Median overhead for '1000 cars' is 2.29785732583
# ...

# %%
plt.plot(o1, label="500 cars")
plt.plot(o2, label="1000 cars")
plt.plot(o3, label="1400 cars")
plt.plot(o4, label="1800 cars")
plt.plot(o5, label="2300 cars")
plt.plot(o6, label="2700 cars")


plt.title("Trip Overheads")
plt.legend(loc='best')
plt.show()

# %%
# print histogram

import numpy as np

n_bins = 6
fig, axes = plt.subplots(nrows=1, ncols=1)
ax0 = axes

c1 = np.ones(500) * -1
c2 = np.ones(500) * -1
c3 = np.ones(500) * -1
c4 = np.ones(500) * -1
c5 = np.ones(500) * -1


c1[0 : len(car200)] = car200
c2[0 : len(car400)] = car400
c3[0 : len(car600)] = car600
c4[0 : len(car800)] = car800
c5[0 : len(car1000)] = car1000

cc = np.stack((c1,c2,c3,c4,c5))
cc = cc.transpose()


#colors = ['#44000d', '#83142c', '#ad1d45']
colors = ['#00a898', '#5ebf8c', '#b6d887' ]
colors = ['#8390A8', '#5A6B8C', '#31466F', '#1B3059', '#162647']
labels = ['200 cars', '400 cars', '600 cars', '800 cars', '1000 cars']
ax0.hist(cc, n_bins, normed=None, histtype='bar', color=colors, label=labels)
#ax0.hist(cc2, n_bins, normed=1, histtype='bar', color='#b6d887', label='car200')
ax0.legend(prop={'size': 10})
ax0.set_title('Trip Overhead of cars 200 till 1000 in a map of Eichstatt')
ax0.set_xlabel('Trip Overheads')
ax0.set_ylabel('Cars')

fig.tight_layout()
plt.show()

print("NOTE ABOUT HISTOGRAM")
print("Ignore the first stack on histogram showing less than 0 overheads. This is a padding on the data required for histogram")
print("---------------------------")
print("x-axis shows the overheads")
print("y-axis shows the no. of cars")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d19f43ca8d6a> in <module>()
#      16 c1[0 : len(car200)] = car200
#      17 c2[0 : len(car400)] = car400
# ---> 18 c3[0 : len(car600)] = car600
#      19 c4[0 : len(car800)] = car800
#      20 c5[0 : len(car1000)] = car1000
#
# NameError: name 'car600' is not defined

# %%
# print histogram
import numpy as np

n_bins = 60
plt.figure()
plt.subplot(231)
plt.hist(o1, n_bins, normed=None, histtype='bar', color="#1B3059", label="200 cars", edgecolor='white')
plt.title('500 cars')
plt.subplot(232)
plt.hist(o2, n_bins, normed=None, histtype='bar', color="#1B3059", label="400 cars", edgecolor='white')
plt.title('1000 cars')
plt.subplot(233)
plt.hist(o3, n_bins, normed=None, histtype='bar', color="#1B3059", label="600 cars", edgecolor='white')
plt.title('1400 cars')
plt.subplot(234)
plt.hist(o4, n_bins, normed=None, histtype='bar', color="#1B3059", label="800 cars", edgecolor='white')
plt.title('1800 cars')
plt.subplot(235)
plt.hist(o5, n_bins, normed=None, histtype='bar', color="#1B3059", label="1000 cars", edgecolor='white')
plt.title('2300 cars')
plt.subplot(236)
plt.hist(o6, n_bins, normed=None, histtype='bar', color="#1B3059", label="1000 cars", edgecolor='white')
plt.title('2700 cars')


plt.tight_layout()
plt.show()


print("x-axis shows the overheads")
print("y-axis shows the no. of cars")
# Out:
# x-axis shows the overheads
# y-axis shows the no. of cars
