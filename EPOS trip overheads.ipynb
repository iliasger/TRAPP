# %%
# %matplotlib inline  
import matplotlib as mpl
import matplotlib.pyplot as plt
from statistics import mean, median, variance 
plt.rcParams['figure.figsize'] = [10, 5]
import pprint

def get_data_from_file(file_name):
    data = []
    with open(file_name, 'r') as results:
        for line in results:
            line = line.split(",")
            trip_duration = float(line[4])
            overhead = float(line[6])
            agent = line[7]
            preference = line[8].replace('\r', '').replace('\n', '')
            
            data.append(overhead)
    return data

# epos_altruistic = sorted(get_data_from_file("results/overhead_a0_b0.csv"))
# epos_selfish = sorted(get_data_from_file("results/overhead_a0_b1.csv"))
# epos_1 = sorted(get_data_from_file("results/overhead_a0_b0.9.csv"))
# epos_2 = sorted(get_data_from_file("results/overhead_a0_b0.5.csv"))

# a1b0 = sorted(get_data_from_file("data/a1-b0/overheads.csv"))
# a1b25 = sorted(get_data_from_file("data/a1-b25/overheads.csv"))
# a1b50 = sorted(get_data_from_file("data/a1-b50/overheads.csv"))
# a1b75 = sorted(get_data_from_file("data/a1-b75/overheads.csv"))
# a1b100 = sorted(get_data_from_file("data/a1-b100/overheads.csv"))

a1b0 = sorted(get_data_from_file("../graph backups/exp-new-utilization/old-utilization-process/a1-b0/overheads.csv"))
a1b25 = sorted(get_data_from_file("../graph backups/exp-new-utilization/old-utilization-process/a1-b25/overheads.csv"))
a1b50 = sorted(get_data_from_file("../graph backups/exp-new-utilization/old-utilization-process/a1-b50/overheads.csv"))
a1b75 = sorted(get_data_from_file("../graph backups/exp-new-utilization/old-utilization-process/a1-b75/overheads.csv"))
a1b100 = sorted(get_data_from_file("../graph backups/exp-new-utilization/old-utilization-process/a1-b100/overheads.csv"))

plt.plot(a1b0, label="a1b0")
plt.plot(a1b25, label="a1b25")
plt.plot(a1b50, label="a1b50")
plt.plot(a1b75, label="a1b75")
plt.plot(a1b100, label="a1b100")

plt.legend(loc='best')
plt.show()

print("Average overhead for 'a1b0' is % s" % (mean(a1b0))) 
print("Average overhead for 'a1b25' is % s" % (mean(a1b25))) 
print("Average overhead for 'a1b50' is % s" % (mean(a1b50))) 
print("Average overhead for 'a1b75' is % s" % (mean(a1b75))) 
print("Average overhead for 'a1b100' is % s" % (mean(a1b100))) 
print("******")
print("median overhead for 'a1b0' is % s" % (median(a1b0))) 
print("median overhead for 'a1b25' is % s" % (median(a1b25))) 
print("median overhead for 'a1b50' is % s" % (median(a1b50))) 
print("median overhead for 'a1b75' is % s" % (median(a1b75))) 
print("median overhead for 'a1b100' is % s" % (median(a1b100)))
print("******")
print("variance overhead for 'a1b0' is % s" % (variance(a1b0))) 
print("variance overhead for 'a1b25' is % s" % (variance(a1b25))) 
print("variance overhead for 'a1b50' is % s" % (variance(a1b50))) 
print("variance overhead for 'a1b75' is % s" % (variance(a1b75))) 
print("variance overhead for 'a1b100' is % s" % (variance(a1b100)))
# Out:
# Average overhead for 'a1b0' is 2.63595939167
# Average overhead for 'a1b25' is 2.61963617825
# Average overhead for 'a1b50' is 2.64286567663
# Average overhead for 'a1b75' is 2.59164685328
# Average overhead for 'a1b100' is 2.61141301415
# ******
# median overhead for 'a1b0' is 2.08677472117
# median overhead for 'a1b25' is 2.08468288789
# median overhead for 'a1b50' is 2.06771630649
# median overhead for 'a1b75' is 2.03539590131
# median overhead for 'a1b100' is 2.06627390332
# ******
# variance overhead for 'a1b0' is 5.18562359385
# variance overhead for 'a1b25' is 4.60871966514
# variance overhead for 'a1b50' is 5.58916289906
# variance overhead for 'a1b75' is 5.36071411274
# variance overhead for 'a1b100' is 5.14116095828
